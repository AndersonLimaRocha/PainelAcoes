# %% [markdown]
# Referencia de vídeo: https://www.youtube.com/watch?v=CzG1_S8mcFc

# %%
try:
  import streamlit
except ImportError:
    # !pip install streamlit
    import streamlit

# %%
#Verificar se já existe o arquivo Streamlit .py, se não existir, descomentar e executar o comando.
#%%writefile /content/drive/MyDrive/Colab_Notebooks/Cotacoes_Acoes/Dashboard.py

# %%
! streamlit run Dashboard.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.68.123:8501
#
#   For better performance, install the Watchdog module:
#
#   $ xcode-select --install
#   $ pip install watchdog
#
# /Users/familialima/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Pl = ult_cotacao / dividendo_soma
# 2024-06-04 17:26:13.310 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 46, in <module>
#     mostra_qntd_linhas(df_categoria)
# NameError: name 'mostra_qntd_linhas' is not defined
# 2024-06-04 17:26:21.516 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 46, in <module>
#     mostra_qntd_linhas(df_categoria)
# NameError: name 'mostra_qntd_linhas' is not defined
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# 2024-06-04 17:26:41.263 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 46, in <module>
#     mostra_qntd_linhas(df_categoria)
# NameError: name 'mostra_qntd_linhas' is not defined
# 2024-06-04 17:26:54.515 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 46, in <module>
#     mostra_qntd_linhas(df_categoria)
# NameError: name 'mostra_qntd_linhas' is not defined
# 2024-06-04 17:29:03.728 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 53, in <module>
#     mostra_qntd_linhas(df_categoria)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 36, in mostra_qntd_linhas
#     st.write(dataframe.head(qntd_linhas).style.format(subset = ['Valor'], formatter="{:.2f}"))
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/io/formats/style_render.py", line 1146, in format
#     data = self.data.loc[subset]
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1097, in __getitem__
#     return self._getitem_tuple(key)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1289, in _getitem_tuple
#     return self._getitem_tuple_same_dim(tup)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 955, in _getitem_tuple_same_dim
#     retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1332, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1272, in _getitem_iterable
#     keyarr, indexer = self._get_listlike_indexer(key, axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1462, in _get_listlike_indexer
#     keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5877, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5938, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['Valor'], dtype='object')] are in the [columns]"
# 2024-06-04 17:29:10.758 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 53, in <module>
#     mostra_qntd_linhas(df_categoria)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 36, in mostra_qntd_linhas
#     st.write(dataframe.head(qntd_linhas).style.format(subset = ['Valor'], formatter="{:.2f}"))
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/io/formats/style_render.py", line 1146, in format
#     data = self.data.loc[subset]
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1097, in __getitem__
#     return self._getitem_tuple(key)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1289, in _getitem_tuple
#     return self._getitem_tuple_same_dim(tup)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 955, in _getitem_tuple_same_dim
#     retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1332, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1272, in _getitem_iterable
#     keyarr, indexer = self._get_listlike_indexer(key, axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1462, in _get_listlike_indexer
#     keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5877, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5938, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['Valor'], dtype='object')] are in the [columns]"
# 2024-06-04 17:29:15.611 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 53, in <module>
#     mostra_qntd_linhas(df_categoria)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 36, in mostra_qntd_linhas
#     st.write(dataframe.head(qntd_linhas).style.format(subset = ['Valor'], formatter="{:.2f}"))
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/io/formats/style_render.py", line 1146, in format
#     data = self.data.loc[subset]
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1097, in __getitem__
#     return self._getitem_tuple(key)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1289, in _getitem_tuple
#     return self._getitem_tuple_same_dim(tup)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 955, in _getitem_tuple_same_dim
#     retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1332, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1272, in _getitem_iterable
#     keyarr, indexer = self._get_listlike_indexer(key, axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1462, in _get_listlike_indexer
#     keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5877, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5938, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['Valor'], dtype='object')] are in the [columns]"
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# 2024-06-04 20:39:55.674 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 55, in <module>
#     mostra_qntd_linhas(df_categoria)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 36, in mostra_qntd_linhas
#     st.write(dataframe.head(qntd_linhas).style.format(subset = ['Valor'], formatter="{:.2f}"))
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/io/formats/style_render.py", line 1146, in format
#     data = self.data.loc[subset]
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1097, in __getitem__
#     return self._getitem_tuple(key)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1289, in _getitem_tuple
#     return self._getitem_tuple_same_dim(tup)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 955, in _getitem_tuple_same_dim
#     retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1332, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1272, in _getitem_iterable
#     keyarr, indexer = self._get_listlike_indexer(key, axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1462, in _get_listlike_indexer
#     keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5877, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5938, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['Valor'], dtype='object')] are in the [columns]"
# 2024-06-04 20:44:12.055 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 55, in <module>
#     mostra_qntd_linhas(df_categoria)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 36, in mostra_qntd_linhas
#     st.write(dataframe.head(qntd_linhas).style.format(subset = ['Valor'], formatter="{:.2f}"))
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/io/formats/style_render.py", line 1146, in format
#     data = self.data.loc[subset]
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1097, in __getitem__
#     return self._getitem_tuple(key)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1289, in _getitem_tuple
#     return self._getitem_tuple_same_dim(tup)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 955, in _getitem_tuple_same_dim
#     retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1332, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1272, in _getitem_iterable
#     keyarr, indexer = self._get_listlike_indexer(key, axis)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py", line 1462, in _get_listlike_indexer
#     keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5877, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 5938, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['Valor'], dtype='object')] are in the [columns]"
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:104: RuntimeWarning: divide by zero encountered in scalar divide
#   Pl = ult_cotacao / dividendo_soma
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2024-06-04 22:07:50.519 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/type_util.py", line 760, in check_python_comparable
#     bool(seq[0] == seq[0])
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py", line 1466, in __nonzero__
#     raise ValueError(
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 55, in <module>
#     categoria = st.sidebar.selectbox('Selecione a categoria para apresentar na tabela', options = Setores)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/metrics_util.py", line 397, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/elements/widgets/selectbox.py", line 203, in selectbox
#     return self._selectbox(
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/elements/widgets/selectbox.py", line 244, in _selectbox
#     check_python_comparable(opt)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/type_util.py", line 765, in check_python_comparable
#     raise StreamlitAPIException(
# streamlit.errors.StreamlitAPIException: Invalid option type provided. Options must be comparable, returning a boolean when used with *==*.
#
# Got **DataFrame**, which cannot be compared. Refactor your code to use elements of comparable types as options, e.g. use indices instead.
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = df.rename(columns={'VALORAJUSTADO':'Cotação no Período','MAIORCOTACAO':'Máxima Cotação Período', 'MENORCOTACAO':'Menor Cotação Período', 'VALORCOMPRA': 'Valor de Compra'})
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   #4. Criando metricas
# 2024-06-05 00:07:05.416 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/scope.py", line 233, in resolve
#     return self.resolvers[key]
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py", line 941, in __getitem__
#     return self.__missing__(key)            # support subclasses that define __missing__
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py", line 933, in __missing__
#     raise KeyError(key)
# KeyError: 'SETORECONOMICO'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/scope.py", line 244, in resolve
#     return self.temps[key]
# KeyError: 'SETORECONOMICO'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 57, in <module>
#     sub = minhasacoes[['SUBSETOR']].query('SETORECONOMICO == @setor').drop_duplicates().reset_index().rename(columns={'SUBSETOR':'Col'})
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py", line 4440, in query
#     res = self.eval(expr, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py", line 4566, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/eval.py", line 336, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 809, in __init__
#     self.terms = self.parse()
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 828, in parse
#     return self._visitor.visit(self.expr)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 421, in visit_Module
#     return self.visit(expr, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 424, in visit_Expr
#     return self.visit(node.value, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 719, in visit_Compare
#     return self.visit(binop)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 535, in visit_BinOp
#     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 455, in _maybe_transform_eq_ne
#     left = self.visit(node.left, side="left")
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 548, in visit_Name
#     return self.term_type(node.id, self.env, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/ops.py", line 86, in __init__
#     self._value = self._resolve_name()
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/ops.py", line 110, in _resolve_name
#     res = self.env.resolve(local_name, is_local=is_local)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/scope.py", line 246, in resolve
#     raise UndefinedVariableError(key, is_local) from err
# pandas.errors.UndefinedVariableError: name 'SETORECONOMICO' is not defined
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# 2024-06-05 00:07:21.274 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/scope.py", line 233, in resolve
#     return self.resolvers[key]
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py", line 941, in __getitem__
#     return self.__missing__(key)            # support subclasses that define __missing__
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py", line 933, in __missing__
#     raise KeyError(key)
# KeyError: 'SETORECONOMICO'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/scope.py", line 244, in resolve
#     return self.temps[key]
# KeyError: 'SETORECONOMICO'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 57, in <module>
#     sub = minhasacoes[['SUBSETOR']].query('SETORECONOMICO == @setor').drop_duplicates().reset_index().rename(columns={'SUBSETOR':'Col'})
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py", line 4440, in query
#     res = self.eval(expr, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py", line 4566, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/eval.py", line 336, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 809, in __init__
#     self.terms = self.parse()
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 828, in parse
#     return self._visitor.visit(self.expr)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 421, in visit_Module
#     return self.visit(expr, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 424, in visit_Expr
#     return self.visit(node.value, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 719, in visit_Compare
#     return self.visit(binop)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 535, in visit_BinOp
#     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 455, in _maybe_transform_eq_ne
#     left = self.visit(node.left, side="left")
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 415, in visit
#     return visitor(node, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/expr.py", line 548, in visit_Name
#     return self.term_type(node.id, self.env, **kwargs)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/ops.py", line 86, in __init__
#     self._value = self._resolve_name()
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/ops.py", line 110, in _resolve_name
#     res = self.env.resolve(local_name, is_local=is_local)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/computation/scope.py", line 246, in resolve
#     raise UndefinedVariableError(key, is_local) from err
# pandas.errors.UndefinedVariableError: name 'SETORECONOMICO' is not defined
# 2024-06-05 00:09:51.537 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 3653, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 147, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 57, in <module>
#     sub = minhasacoes[['SUBSETOR']][minhasacoes['SETORECONOMICO' == setor]] .drop_duplicates().reset_index().rename(columns={'SUBSETOR':'Col'})
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py", line 3761, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 3655, in get_loc
#     raise KeyError(key) from err
# KeyError: False
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# 2024-06-05 00:10:08.640 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py", line 3653, in get_loc
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data = df[df["VALORDIVIDENDO"]>0]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data = df[df["VALORDIVIDENDO"]>0]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delta = round(((ult_cotacao- vlpago)/ vlpago)*100,2) #A variacao da cotacao no periodo
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dividendo = data["VALORDIVIDENDO"].mean()
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dividendo = data["VALORDIVIDENDO"].mean()
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dividendo = data["VALORDIVIDENDO"].mean()
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dividendo = data["VALORDIVIDENDO"].mean()
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historico = data["VALORDIVIDENDO"].count()
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historico = data["VALORDIVIDENDO"].count()
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historico = data["VALORDIVIDENDO"].count()
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historico = data["VALORDIVIDENDO"].count()
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   historico = data["VALORDIVIDENDO"].count()
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maior_cotacao = round(df["Cotação no Período"].max(), 2) #Pega a maior cotacao do periodo
# 2024-06-05 01:09:25.623 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 124, in <module>
#     ult_atualizacao = pd.to_datetime(df.index.max().replace(' 00:00:00',''), format='%Y-%m-%d') #Data da ultima att
# AttributeError: 'numpy.int64' object has no attribute 'replace'
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# 2024-06-05 01:09:55.459 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 124, in <module>
#     ult_atualizacao = pd.to_datetime(df.index.max(), format='%Y-%m-%d') #Data da ultima att
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py", line 1084, in to_datetime
#     result = convert_listlike(np.array([arg]), format)[0]
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py", line 453, in _convert_listlike_datetimes
#     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py", line 484, in _array_strptime_with_fallback
#     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#   File "pandas/_libs/tslibs/strptime.pyx", line 530, in pandas._libs.tslibs.strptime.array_strptime
#   File "pandas/_libs/tslibs/strptime.pyx", line 351, in pandas._libs.tslibs.strptime.array_strptime
# ValueError: time data "1239" doesn't match format "%Y-%m-%d", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# 2024-06-05 01:11:37.045 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 124, in <module>
#     ult_atualizacao = str(df.index.max()).replace(' 00:00:00','').to_datetime() #Data da ultima att
# AttributeError: 'str' object has no attribute 'to_datetime'
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2024-06-05 01:14:21.987 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 107, in <module>
#     dtcompra = dt.datetime.strptime(dtcompra, '%d-%m-%Y')
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '2019-06-06' does not match format '%d-%m-%Y'
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df = minhasacoes[minhasacoes['ACAO'] == tkt]
# 2024-06-05 01:21:48.633 Uncaught app exception
# Traceback (most recent call last):
#   File "pandas/_libs/tslibs/conversion.pyx", line 245, in pandas._libs.tslibs.conversion._TSObject.ensure_reso
#   File "pandas/_libs/tslibs/np_datetime.pyx", line 614, in pandas._libs.tslibs.np_datetime.convert_reso
# OverflowError: value too large
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 125, in <module>
#     ult_atualizacao = pd.to_datetime(str(df.index.max()).replace(' 00:00:00','')) # str(df.index.max()).replace(' 00:00:00','') #Data da ultima att
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py", line 1084, in to_datetime
#     result = convert_listlike(np.array([arg]), format)[0]
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py", line 455, in _convert_listlike_datetimes
#     result, tz_parsed = objects_to_datetime64ns(
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/arrays/datetimes.py", line 2177, in objects_to_datetime64ns
#     result, tz_parsed = tslib.array_to_datetime(
#   File "pandas/_libs/tslib.pyx", line 402, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 551, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslib.pyx", line 519, in pandas._libs.tslib.array_to_datetime
#   File "pandas/_libs/tslibs/conversion.pyx", line 248, in pandas._libs.tslibs.conversion._TSObject.ensure_reso
# pandas._libs.tslibs.np_datetime.OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1239, at position 0
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
# 2024-06-05 01:22:28.201 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py", line 125, in <module>
#     ult_atualizacao = pd.to_datetime(str(df.index.max()).replace(' 00:00:00',''), format='%Y-%m-%d') # str(df.index.max()).replace(' 00:00:00','') #Data da ultima att
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py", line 1084, in to_datetime
#     result = convert_listlike(np.array([arg]), format)[0]
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py", line 453, in _convert_listlike_datetimes
#     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#   File "/Users/familialima/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py", line 484, in _array_strptime_with_fallback
#     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#   File "pandas/_libs/tslibs/strptime.pyx", line 530, in pandas._libs.tslibs.strptime.array_strptime
#   File "pandas/_libs/tslibs/strptime.pyx", line 351, in pandas._libs.tslibs.strptime.array_strptime
# ValueError: time data "1239" doesn't match format "%Y-%m-%d", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
# /Users/familialima/Documents/GitHub/PainelAcoes/Dashboard.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VALORCOMPRA'] = float(vlpago)
